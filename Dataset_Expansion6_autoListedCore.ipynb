# %% [markdown]
# <a href="https://colab.research.google.com/github/katha815/ADME-Classifier/blob/main/Dataset_Expansion6_autoListedCore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Results are reliable: same data size with manual version!

# %%
Core_genes = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/ADME Project/Core ADME Genes.csv")

# %%
# Data preparation (real run)
file_paths = []

# List of TSV file paths
for i in range(len(Core_genes['Gene'])):
  if Core_genes['Listed?'][i]==1:
    gene_name = Core_genes['Gene'][i]
    file_paths.append(f'/content/gdrive/My Drive/Colab Notebooks/ADME Project/{gene_name}.tsv')

# Create an empty list to store DataFrames
dfs = []

# Read each TSV file and append its DataFrame to the list
for file_path in file_paths:
    try:
        df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
        dfs.append(df)
    except pd.errors.ParserError:
        print(f"Error reading file: {file_path}")

# Concatenate the DataFrames into a single DataFrame
raw_df = pd.concat(dfs, ignore_index=True)

# Save the combined DataFrame as a CSV file
#raw_df.to_csv('/content/gdrive/My Drive/Colab Notebooks/ADME Project/ListedCore_raw_auto.csv', index=False)
# Out:
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)
# <ipython-input-3-1b968528f97f>:16: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(file_path, sep='\t', error_bad_lines=False)

# %%
# Ref/Alter rows creation (Real-run)
data = raw_df

# Define the search patterns and corresponding replacement values
patterns = ['Allele A ', 'Allele C ', 'Allele G ', 'Allele T ']
patterns2 = ['allele A', 'allele C', 'allele G', 'allele T']
replacements = ['A', 'C', 'G', 'T']

# Create the two new columns using the search patterns and replacements
data['Alter'] = data['Association'].apply(lambda x: next((replacements[i] for i, pattern in enumerate(patterns) if pattern in x), np.nan))
data['Ref'] = data['Association'].apply(lambda x: next((replacements[i] for i, pattern2 in enumerate(patterns2) if pattern2 in x), np.nan))

data
# Out:
#       PharmGKB ID                           Variant        Literature  \
# 0       827921753                         rs3740066     PMID:22630058
# 1       981939846                         rs3740066     PMID:18444945
# 2      1451129980                          rs717620     PMID:31648372
# 3       827824467                         rs3740066     PMID:22256867
# 4       827844958                         rs2804398     PMID:21449672
# ...           ...                               ...               ...
# 6552   1451893624                         rs1142345     PMID:36143183
# 6553   1184349029  TPMT*1; TPMT*2; TPMT*3A; TPMT*3C  PMCID:PMC3080646
# 6554   1000539737                        rs12201199  PMCID:PMC3883563
# 6555   1184169832                   TPMT*1; TPMT*3A     PMID:18987660
# 6556   1000539742                         rs1800460  PMCID:PMC3883563
#
#                                     Drugs  \
# 0                          antiepileptics
# 1     cyclosporine; mycophenolate mofetil
# 2     Drugs For Treatment Of Tuberculosis
# 3                          antiepileptics
# 4                          antiepileptics
# ...                                   ...
# 6552                         azathioprine
# 6553                       mercaptopurine
# 6554                            cisplatin
# 6555                       mercaptopurine
# 6556                            cisplatin
#
#                                             Association Significance  \
# 0     Genotypes CT + TT are associated with increase...          yes
# 1     Genotypes CT + TT are not associated with incr...           no
# 2     Allele T is not associated with risk of Toxic ...           no
# 3     Genotypes CT + TT are not associated with incr...           no
# 4     Allele T is not associated with resistance to ...           no
# ...                                                 ...          ...
# 6552  Genotypes CC + CT (assigned as poor metabolize...          yes
# 6553  TPMT *1/*2 + *1/*3A + *1/*3C is associated wit...          yes
# 6554  Allele T is not associated with risk of Ototox...           no
# 6555  TPMT *1/*3A is associated with decreased dose ...          yes
# 6556  Allele T is not associated with risk of Ototox...           no
#
#        P-Value  # of Cases  # of Controls Biogeographical Groups  \
# 0      = 0.038       217.0          320.0             East Asian
# 1       = 0.63       237.0            NaN               European
# 2      = 0.514       746.0            NaN             East Asian
# 3        = 0.8       357.0          247.0               European
# 4       = 0.75       586.0            NaN             East Asian
# ...        ...         ...            ...                    ...
# 6552  = 0.0004      1050.0            NaN             East Asian
# 6553  < 0.0001        65.0            NaN                Unknown
# 6554     = 0.5        64.0          149.0        Multiple groups
# 6555   < 0.001       312.0            NaN               European
# 6556    = 0.11        64.0          149.0        Multiple groups
#
#      Phenotype Categories  Pediatric  \
# 0                Efficacy      False
# 1                Efficacy      False
# 2                Toxicity      False
# 3                Efficacy      False
# 4                Efficacy      False
# ...                   ...        ...
# 6552             Toxicity      False
# 6553        Metabolism/PK       True
# 6554             Toxicity       True
# 6555               Dosage       True
# 6556             Toxicity       True
#
#                                            More Details  Genes Alter  Ref
# 0     This SNP was also part of haplotype associated...  ABCC2   NaN  NaN
# 1     No association was found with biopsy-proven ac...  ABCC2   NaN  NaN
# 2     Please note that alleles have been complemente...  ABCC2     T    C
# 3                                                   NaN  ABCC2   NaN  NaN
# 4     Epilepsy patients on antiepileptic drug (AED) ...  ABCC2     T    A
# ...                                                 ...    ...   ...  ...
# 6552  Effect is described for "non-NM genotype", "A ...   TPMT   NaN  NaN
# 6553  ITPA SNPs were assessed as well and included i...   TPMT   NaN  NaN
# 6554                                                NaN   TPMT     T    A
# 6555  Patients were in the maintenance phase of trea...   TPMT   NaN  NaN
# 6556                                                NaN   TPMT     T    C
#
# [6557 rows x 16 columns]

# %%
data.dtypes
# Out:
# PharmGKB ID                 int64
# Variant                    object
# Literature                 object
# Drugs                      object
# Association                object
# Significance               object
# P-Value                    object
# # of Cases                float64
# # of Controls             float64
# Biogeographical Groups     object
# Phenotype Categories       object
# Pediatric                    bool
# More Details               object
# Genes                      object
# Alter                      object
# Ref                        object
# dtype: object

# %% [markdown]
# ## Arthitecture and Principal:
# This code should be able to rearrange data downloaded from PharmGKB with only two added columns ("Alter" and "Ref"), and produces a usable datasheet with chormosome, location, alter, ref and a label of pharmacogenetic significance.

# %%
# Load data
#data = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/ADME Project/listed_core_o.csv")

# %%
# Only select SNPs which pharmacogenetic significance is known

data['numeric'] = data['Significance'].map({'yes': 1, 'no': 0})
data_dropped = data.dropna(subset=['numeric','Alter'])

# %%
# Sort with variant, alternative base and significant label
#This sorted data set can refered later for certain variant location
#as it includes all related literature.

data_sorted = data_dropped.sort_values(['Variant','Alter','Significance'])

data_sorted.to_csv('/content/gdrive/My Drive/Colab Notebooks/ADME Project/ListedCore_o_auto.csv')

# %%
# If for the same alternative base and same variant location, there are both significant report and non-siginificant report,
#delete the later.

data_unique = data_sorted.drop_duplicates(subset=['Variant', 'Alter'], keep='last')

data_unique
# Out:
#       PharmGKB ID     Variant        Literature  \
# 817    1448993544   rs1042389  PMCID:PMC3940150
# 5966   1450045235  rs10444413     PMID:29791011
# 2884    982033113  rs10509680     PMID:20833655
# 2754    981859317  rs10509681  PMCID:PMC3660078
# 2767   1447954627  rs10509681     PMID:24704000
# ...           ...         ...               ...
# 3387   1184757013   rs9332127  PMCID:PMC4134280
# 2939   1447519965   rs9332197  PMCID:PMC3330749
# 3279   1446534354   rs9332238  PMCID:PMC4573240
# 3905    827788986   rs9332239     PMID:15284535
# 3897   1451919700   rs9332241  PMCID:PMC9537548
#
#                                                   Drugs  \
# 817   efavirenz; non-nucleoside reverse transcriptas...
# 5966                                       methotrexate
# 2884                                           warfarin
# 2754                                         paclitaxel
# 2767                              docetaxel; paclitaxel
# ...                                                 ...
# 3387                                           warfarin
# 2939                                           warfarin
# 3279                                           warfarin
# 3905                                        tolbutamide
# 3897                                           warfarin
#
#                                             Association Significance  \
# 817   Allele C is not associated with response to ef...           no
# 5966  Allele C is not associated with clearance of m...           no
# 2884  Allele T is associated with decreased dose of ...          yes
# 2754  Allele C is associated with increased risk of ...          yes
# 2767  Allele T is not associated with response to do...           no
# ...                                                 ...          ...
# 3387  Allele G is not associated with dose of warfar...           no
# 2939  Allele C is associated with time to achieve st...          yes
# 3279  Allele G is associated with increased dose of ...          yes
# 3905  Allele T is associated with decreased catalyti...          yes
# 3897  Allele T is associated with decreased metaboli...          yes
#
#          P-Value  # of Cases  # of Controls  \
# 817       = 0.80        91.0            NaN
# 5966    > 0.0001       187.0            NaN
# 2884   = 3.84E-7      1508.0            NaN
# 2754     = 0.004       411.0            NaN
# 2767     = 0.888        22.0           36.0
# ...          ...         ...            ...
# 3387      > 0.20       787.0            NaN
# 2939  = 3.45e-04       311.0            NaN
# 3279   = 4.4e-13       367.0            NaN
# 3905         NaN         NaN            NaN
# 3897  = 5.38E-10       524.0            NaN
#
#                                  Biogeographical Groups Phenotype Categories  \
# 817                                     Multiple groups             Efficacy
# 5966                                            Unknown        Metabolism/PK
# 2884                                         East Asian               Dosage
# 2754  Multiple groups, combined European American an...             Toxicity
# 2767                                Central/South Asian             Efficacy
# ...                                                 ...                  ...
# 3387                                         East Asian               Dosage
# 2939                         Multiple groups, 98% white             Efficacy
# 3279                        Multiple groups, Brazilian                Dosage
# 3905                                                NaN        Metabolism/PK
# 3897                                Sub-Saharan African        Metabolism/PK
#
#       Pediatric                                       More Details    Genes  \
# 817       False                                                NaN   CYP2B6
# 5966      False                                                NaN  SLCO1B1
# 2884      False                                                NaN   CYP2C9
# 2754      False  Risk increases per copy of the C allele (indic...   CYP2C8
# 2767      False  Patients with complete and partial pathologica...   CYP2C8
# ...         ...                                                ...      ...
# 3387      False  Samples, genotypes and INRs from a cohort of 5...   CYP2C9
# 2939      False                                                NaN   CYP2C9
# 3279      False  The G allele was strongly associated with high...   CYP2C9
# 3905      False                                       p value 0.05   CYP2C9
# 3897      False  measured as decreased S-warfarin/R-warfarin ra...   CYP2C9
#
#      Alter  Ref  numeric
# 817      C  NaN      0.0
# 5966     C    T      0.0
# 2884     T    G      1.0
# 2754     C    T      1.0
# 2767     T    C      0.0
# ...    ...  ...      ...
# 3387     G    C      0.0
# 2939     C    T      1.0
# 3279     G    A      1.0
# 3905     T  NaN      1.0
# 3897     T    C      1.0
#
# [278 rows x 17 columns]

# %%
import requests

# Create empty lists to store the genomic information
chromosomes = []
locations = []
reference_bases = []

# Base URL for Ensembl REST API
base_url = 'https://rest.ensembl.org'

# Iterate over rsIDs
for rsID in data_unique['Variant']:
    # Construct the API endpoint URL
    endpoint = f'{base_url}/variation/human/{rsID}?phenotypes=1'

    # Send GET request to the API
    response = requests.get(endpoint, headers={'Content-Type': 'application/json'})

    # Check if the request was successful
    if response.status_code == 200:
        # Extract relevant information from the response
        data = response.json()
        chromosome = data['mappings'][0]['seq_region_name']
        location = data['mappings'][0]['start']
        reference_base = data['mappings'][0]['allele_string'].split('/')[0]

        # Append the genomic information to the respective lists
        chromosomes.append(chromosome)
        locations.append(location)
        reference_bases.append(reference_base)
    else:
        # If there was an error, append None to the lists
        chromosomes.append(None)
        locations.append(None)
        reference_bases.append(None)

# Create a new DataFrame with the genomic information
search_df = pd.DataFrame({
    'Chromosome': chromosomes,
    'Location': locations,
    'Reference Base': reference_bases
})

# %%
# Combine the search results with orginal dataset
search_df.set_index(data_unique.index, inplace=True)
combined_df = data_unique.join(search_df)

# %%
# Filter duplicates

combined_df['Combination'] = combined_df[['Alter', 'Ref']].apply(lambda x: ''.join(sorted(x.values.astype(str))), axis=1)
# Drop rows where Column1 and Combination values are the same, and Column4 is 'no'
filterd_df = combined_df.dropna(subset=['Chromosome','Location','Reference Base'])
filterd_df = filterd_df[~((combined_df.duplicated(subset=['Location', 'Combination']) & (combined_df['numeric'] == 0)) |
      ((combined_df['numeric'] == 1) & combined_df.duplicated(subset=['Location', 'Combination']) & (combined_df.groupby('Location')['numeric'].transform('max') == 1)))]
# Out:
# <ipython-input-12-07e5148f1181>:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filterd_df = filterd_df[~((combined_df.duplicated(subset=['Location', 'Combination']) & (combined_df['numeric'] == 0)) |

# %%
# Finalizing
#"Pediatric" deleted due to irrelavance
final1 = filterd_df[['Chromosome','Genes','Location','Reference Base','Alter','Combination','numeric','Literature','Drugs','Association','More Details']]

# %%
# Filter again
#1)Combination Combination - Reference Base
#2)Delete nan Combination
#3)Change the rest Combination to "True Alter"
filtered2 = final1
filtered2['Combination'] = final1.apply(lambda row: str(row['Combination']).replace(str(row['Reference Base']), ''), axis=1)
# Out:
# <ipython-input-14-4d14096c7fa8>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered2['Combination'] = final1.apply(lambda row: str(row['Combination']).replace(str(row['Reference Base']), ''), axis=1)

# %%
data_dropped2 = filtered2[~(filtered2['Combination'] == 'nan')]

# %%
# Final 2: Calculate True Alter
final2 = data_dropped2
final2['Combination'] = data_dropped2.apply(lambda row: row['Alter'] if str(row['Alter']) != str(row['Reference Base']) else str(row['Combination']), axis=1)
# Out:
# <ipython-input-16-80a9026e924b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final2['Combination'] = data_dropped2.apply(lambda row: row['Alter'] if str(row['Alter']) != str(row['Reference Base']) else str(row['Combination']), axis=1)

# %%
# Final 3: Delete irrelevant column
final3 = final2.drop(columns='Alter')
final3 = final3.rename(columns={'Combination': 'Altered Base'})
final3 = final3[~(final3['Altered Base'] == None)]
final3
# Out:
#      Chromosome    Genes    Location Reference Base Altered Base  numeric  \
# 817          19   CYP2B6  41018248.0              T            C      0.0
# 5966         12  SLCO1B1  21164734.0              T            C      0.0
# 2884         10   CYP2C9  94974582.0              G            T      1.0
# 2754         10   CYP2C8  95038992.0              T            C      1.0
# 3824         10   CYP2C9  94981296.0              A            C      1.0
# ...         ...      ...         ...            ...          ...      ...
# 3665         10   CYP2C9  94947714.0              G            C      0.0
# 2939         10   CYP2C9  94981151.0              T            C      1.0
# 3279         10   CYP2C9  94988735.0              G            A      1.0
# 3905         10   CYP2C9  94989020.0              C            T      1.0
# 3897         10   CYP2C9  94989116.0              C            T      1.0
#
#             Literature                                              Drugs  \
# 817   PMCID:PMC3940150  efavirenz; non-nucleoside reverse transcriptas...
# 5966     PMID:29791011                                       methotrexate
# 2884     PMID:20833655                                           warfarin
# 2754  PMCID:PMC3660078                                         paclitaxel
# 3824  PMCID:PMC4134280                                           warfarin
# ...                ...                                                ...
# 3665     PMID:22248286                                           warfarin
# 2939  PMCID:PMC3330749                                           warfarin
# 3279  PMCID:PMC4573240                                           warfarin
# 3905     PMID:15284535                                        tolbutamide
# 3897  PMCID:PMC9537548                                           warfarin
#
#                                             Association  \
# 817   Allele C is not associated with response to ef...
# 5966  Allele C is not associated with clearance of m...
# 2884  Allele T is associated with decreased dose of ...
# 2754  Allele C is associated with increased risk of ...
# 3824  Allele A is associated with increased dose of ...
# ...                                                 ...
# 3665  Allele C is not associated with increased dose...
# 2939  Allele C is associated with time to achieve st...
# 3279  Allele G is associated with increased dose of ...
# 3905  Allele T is associated with decreased catalyti...
# 3897  Allele T is associated with decreased metaboli...
#
#                                            More Details
# 817                                                 NaN
# 5966                                                NaN
# 2884                                                NaN
# 2754  Risk increases per copy of the C allele (indic...
# 3824  Samples, genotypes and INRs from a cohort of 5...
# ...                                                 ...
# 3665  No association was found between this variant ...
# 2939                                                NaN
# 3279  The G allele was strongly associated with high...
# 3905                                       p value 0.05
# 3897  measured as decreased S-warfarin/R-warfarin ra...
#
# [240 rows x 10 columns]

# %%
np.shape(final3)
# Out:
# (240, 10)

# %%
final4 = final3.sort_values(['Chromosome', 'Genes'])
final4
# Out:
#      Chromosome          Genes    Location Reference Base Altered Base  \
# 206          10          ABCC2  99861014.0              C            G
# 135          10          ABCC2  99852563.0              C            T
# 34           10          ABCC2  99843765.0              T            C
# 46           10          ABCC2  99804028.0              C            T
# 37           10          ABCC2  99804266.0              C            T
# ...         ...            ...         ...            ...          ...
# 5594          7         CYP3A4  99760901.0              A            G
# 5706          7         CYP3A4  99758184.0          TTTTT            T
# 5737          7         CYP3A4  99761528.0              C            T
# 5645          7  CYP3A; CYP3A4  99762047.0              G            A
# 5742          7  CYP3A; CYP3A4  99760836.0              G            A
#
#       numeric        Literature  \
# 206       1.0     PMID:18294295
# 135       1.0     PMID:27180762
# 34        1.0     PMID:30100615
# 46        1.0     PMID:30100615
# 37        0.0     PMID:21449672
# ...       ...               ...
# 5594      1.0     PMID:12966368
# 5706      0.0  PMCID:PMC7235792
# 5737      1.0  PMCID:PMC3237759
# 5645      1.0     PMID:11470997
# 5742      0.0     PMID:15634941
#
#                                                   Drugs  \
# 206                                           docetaxel
# 135                                         vincristine
# 34                                         rosuvastatin
# 46                                         rosuvastatin
# 37                                       antiepileptics
# ...                                                 ...
# 5594                                         tacrolimus
# 5706  ambrisentan; aripiprazole; atorvastatin; donep...
# 5737                                         tacrolimus
# 5645                                                NaN
# 5742                                         nifedipine
#
#                                             Association  \
# 206   Allele G is associated with increased risk of ...
# 135   Allele T is associated with decreased likeliho...
# 34    Allele C is associated with decreased exposure...
# 46    Allele T is associated with decreased exposure...
# 37    Allele C is not associated with resistance to ...
# ...                                                 ...
# 5594  Allele G is associated with decreased dose of ...
# 5706  Allele T is not associated with metabolism of ...
# 5737  Allele C is associated with tacrolimus concent...
# 5645  Allele A is associated with decreased steady-s...
# 5742  Allele A is not associated with decreased meta...
#
#                                            More Details
# 206   Study genotyped 84 patients from BioBank Japan...
# 135   when comparing zero neurotoxicity vs grades 1-...
# 34                                                  NaN
# 46                                                  NaN
# 37    Epilepsy patients on antiepileptic drug (AED) ...
# ...                                                 ...
# 5594  as calculated by increased tacrolimus dose-adj...
# 5706  No significant changes in PK parameters in the...
# 5737  This variant is in linkage disequilibrium with...
# 5645  In a bacterial heterologous expression system,...
# 5742  In vitro.  Metabolism was not significantly di...
#
# [240 rows x 10 columns]

# %%
final4.to_csv('/content/gdrive/My Drive/Colab Notebooks/ADME Project/ListedCore_auto.csv')
